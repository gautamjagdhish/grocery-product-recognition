# %%
# verify CUDA
! /usr/local/cuda/bin/nvcc --version

# symbolic link
! ln -s /content/drive/My\ Drive/asm_coop /asm
% cd /asm/darknet
! chmod +x darknet
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# ln: failed to create symbolic link '/asm/asm_coop': Operation not supported
# /content/drive/My Drive/asm_coop/darknet

# %%
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# # Train

# %%
# %%capture
# !./darknet detector train data/obj.data cfg/mvtec.cfg /asm/project_mvtec/yolo_config/backup/mvtec_last.weights -dont_show
